# %% [markdown]
# ## Study notes

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# absl-py                   2.1.0
# aiohappyeyeballs          2.4.4
# aiohttp                   3.11.11
# aiosignal                 1.3.2
# alembic                   1.14.0
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.7.0
# archspec                  0.2.3
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# astunparse                1.6.3
# async_generator           1.10
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# blinker                   1.9.0
# bokeh                     3.6.2
# boltons                   24.0.0
# Bottleneck                1.4.2
# Brotli                    1.1.0
# cached-property           1.5.2
# ...

# %% [markdown]
# ## Classifications
#
# "**Classification** is one of the main instances of supervised learning. Given a training set of data containing observations and their associated categorical outputs, the goal of classification is to learn a general rule that correctly maps the _observations_ (also called _features_ or _predictive variables_) to the target _categories_ (also called _labels_ or _classes_). ”
#
# Excerpt From
# Python Machine Learning By Example_Fourth Edition
# Yuxi (Hayden) Liu

# %% [markdown]
# ### Types of **Classifications**
#
# * Binary
# * Multiclass
# * Multi-label
